# %%
import requests
from datetime import datetime


def save_url_content(url):
    res = requests.get(url)
    content = res.content.decode("utf-8")[0:500]

    # Format -> 20241030_155221.txt
    file_name = f"{datetime.now():%Y%m%d_%H%M%S}.txt"
    with open(file_name, "w") as f:
        f.write(content)

    return file_name


url = input("URLを入力してください: ")
file_name = save_url_content(url)
print(f"Content saved in: {file_name}")
# Out:
# Content saved in: 20260219_083132.txt
